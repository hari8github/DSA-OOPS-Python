# %% [markdown]
# Stacks

# %%
# LIFO

stack = []
print(stack)
# Out:
# []

# %%
stack.append(5)

# %%
stack.append(7)
stack.append(2)

print(stack)
# Out:
# [5, 7, 2]

# %%
x = stack.pop()
print(x)
print(stack)
# Out:
# 2
# [5, 7]

# %%
print(stack[-1])
# Out:
# 7

# %%
if stack:
    print(True)
# Out:
# True

# %% [markdown]
# Queues

# %%
from collections import deque

q = deque()
print(q)
# Out:
# deque([])

# %%
q.append(1)
q.append(2)
q.append(3)

print(q)
# Out:
# deque([1, 2, 3])

# %%
# Dequeue
q.popleft()
print(q)
# Out:
# deque([2, 3])

# %%
q [0]
# Out:
# 2

# %%
q[-1]
# Out:
# 3
